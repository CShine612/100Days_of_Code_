# %% [markdown]
# # Introduction
#
# In this notebook, we will do a comprehensive analysis of the Android app market by comparing thousands of apps in the Google Play store.

# %% [markdown]
# # About the Dataset of Google Play Store Apps & Reviews

# %% [markdown]
# **Data Source:** <br>
# App and review data was scraped from the Google Play Store by Lavanya Gupta in 2018. Original files listed [here](
# https://www.kaggle.com/lava18/google-play-store-apps).

# %% [markdown]
# # Import Statements

# %%
import pandas as pd
import plotly.express as px

# %% [markdown]
# # Notebook Presentation

# %%
# Show numeric output in decimal format e.g., 2.15
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# # Read the Dataset

# %%
df_apps = pd.read_csv('apps.csv')

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# **Challenge**: How many rows and columns does `df_apps` have? What are the column names? Look at a random sample of 5 different rows with [.sample()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sample.html).

# %%
print(df_apps.shape)
df_apps.sample(5)
# Out:
# (10841, 12)
#                                                    App       Category  Rating  \
# 474                           Mehmet Emin Ay İlahileri         FAMILY     nan
# 8298                        bigbasket - online grocery       SHOPPING    4.30
# 3087  AP Physics 1 Prep: Practice Tests and Flashcards         FAMILY    4.40
# 7491       Builder Craft: House Building & Exploration         FAMILY    4.20
# 9045                                Puffin Web Browser  COMMUNICATION    4.30
#
#       Reviews  Size_MBs    Installs  Type Price Content_Rating         Genres  \
# 474         0      5.10          10  Free     0       Everyone  Entertainment
# 8298   216741      9.30   5,000,000  Free     0       Everyone       Shopping
# 3087       29      5.30       5,000  Free     0       Everyone      Education
# 7491    20807     52.00   1,000,000  Free     0   Everyone 10+     Simulation
# 9045   541389      3.50  10,000,000  Free     0       Everyone  Communication
#
# ...

# %% [markdown]
# ### Drop Unused Columns
#
# **Challenge**: Remove the columns called `Last_Updated` and `Android_Version` from the DataFrame. We will not use these columns.

# %%
df_apps.drop("Last_Updated", inplace=True, axis=1)
df_apps.drop("Android_Ver", inplace=True, axis=1)

# %% [markdown]
# ### Find and Remove NaN values in Ratings
#
# **Challenge**: How may rows have a NaN value (not-a-number) in the Ratings column? Create DataFrame called `df_apps_clean` that does not include these rows.

# %%
df_apps.isna().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size_MBs             0
# Installs             0
# Type                 1
# Price                0
# Content_Rating       0
# Genres               0
# dtype: int64

# %%
df_apps_clean = df_apps.dropna()

# %% [markdown]
# ### Find and Remove Duplicates
#
# **Challenge**: Are there any duplicates in data? Check for duplicates using the [.duplicated()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html) function. How many entries can you find for the "Instagram" app? Use [.drop_duplicates()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop_duplicates.html) to remove any duplicates from `df_apps_clean`.

# %%
df_apps_clean.duplicated()
# Out:
# 21       False
# 28       False
# 47       False
# 82       False
# 99       False
# 114      False
# 126      False
# 128      False
# 141      False
# 151      False
# 154      False
# 162      False
# 171      False
# 174      False
# 179      False
# 181      False
# 184      False
# 185      False
# 186      False
# 201      False
# 215      False
# 226      False
# 227      False
# 229      False
# 230      False
# 231      False
# 233      False
# 234      False
# 235      False
# 237      False
#          ...
# 10811    False
# 10812    False
# 10813    False
# 10814    False
# 10815    False
# 10816    False
# 10817    False
# 10818    False
# 10819    False
# 10820    False
# 10821    False
# 10822    False
# 10823    False
# 10824    False
# 10825    False
# 10826     True
# 10827    False
# 10828    False
# 10829    False
# 10830    False
# 10831    False
# 10832     True
# 10833    False
# 10834    False
# 10835    False
# 10836    False
# 10837    False
# ...

# %%
df_apps_clean = df_apps_clean.drop_duplicates(subset={"App", "Type", "Price"})

# %% [markdown]
# # Find Highest Rated Apps
#
# **Challenge**: Identify which apps are the highest rated. What problem might you encounter if you rely exclusively on ratings alone to determine the quality of an app?

# %%
df_apps_clean.sort_values("Rating").tail()
# Out:
#                                                     App            Category  \
# 1252         Girls Live Talk - Free Text and Video Chat              DATING
# 1254                            Online Girls Chat Group              DATING
# 1257  Kolkata News:Anandbazar Patrika,ei samay&AllRa...  NEWS_AND_MAGAZINES
# 1229                                Cr Aviation Academy              FAMILY
# 21                                  KBA-EZ Health Guide             MEDICAL
#
#       Rating  Reviews  Size_MBs Installs  Type Price Content_Rating  \
# 1252    5.00        6      5.00      100  Free     0     Mature 17+
# 1254    5.00        5      5.00      100  Free     0     Mature 17+
# 1257    5.00       10      5.00      100  Free     0       Everyone
# 1229    5.00        7     22.00      100  Free     0       Everyone
# 21      5.00        4     25.00        1  Free     0       Everyone
#
#                 Genres
# 1252            Dating
# 1254            Dating
# 1257  News & Magazines
# ...

# %% [markdown]
# # Find 5 Largest Apps in terms of Size (MBs)
#
# **Challenge**: What's the size in megabytes (MB) of the largest Android apps in the Google Play Store. Based on the data, do you think there could be limit in place or can developers make apps as large as they please?

# %%
df_apps_clean.sort_values("Size_MBs").tail()
# Out:
#                                  App Category  Rating  Reviews  Size_MBs  \
# 7928   Stickman Legends: Shadow Wars     GAME    4.40    38419    100.00
# 10295                SimCity BuildIt   FAMILY    4.50  4218587    100.00
# 8719      Draft Simulator for FUT 18   SPORTS    4.60   162933    100.00
# 10687         Hungry Shark Evolution     GAME    4.50  6074334    100.00
# 9943           Miami crime simulator     GAME    4.00   254518    100.00
#
#           Installs  Type  Price Content_Rating      Genres
# 7928     1,000,000  Paid  $0.99   Everyone 10+      Action
# 10295   50,000,000  Free      0   Everyone 10+  Simulation
# 8719     5,000,000  Free      0       Everyone      Sports
# 10687  100,000,000  Free      0           Teen      Arcade
# 9943    10,000,000  Free      0     Mature 17+      Action

# %% [markdown]
# # Find the 5 App with Most Reviews
#
# **Challenge**: Which apps have the highest number of reviews? Are there any paid apps among the top 50?

# %%
df_apps_clean.sort_values("Reviews").tail()
# Out:
#                                             App       Category  Rating  \
# 10650                            Clash of Clans           GAME    4.60
# 10784  Messenger – Text and Video Chat for Free  COMMUNICATION    4.00
# 10806                                 Instagram         SOCIAL    4.50
# 10785                        WhatsApp Messenger  COMMUNICATION    4.40
# 10805                                  Facebook         SOCIAL    4.10
#
#         Reviews  Size_MBs       Installs  Type Price Content_Rating  \
# 10650  44891723     98.00    100,000,000  Free     0   Everyone 10+
# 10784  56642847      3.50  1,000,000,000  Free     0       Everyone
# 10806  66577313      5.30  1,000,000,000  Free     0           Teen
# 10785  69119316      3.50  1,000,000,000  Free     0       Everyone
# 10805  78158306      5.30  1,000,000,000  Free     0           Teen
#
#               Genres
# 10650       Strategy
# 10784  Communication
# 10806         Social
# 10785  Communication
# ...

# %% [markdown]
# # Plotly Pie and Donut Charts - Visualise Categorical Data: Content Ratings

# %%
ratings = df_apps_clean.Content_Rating.value_counts()
ratings
# Out:
# Everyone           6621
# Teen                912
# Mature 17+          357
# Everyone 10+        305
# Adults only 18+       3
# Unrated               1
# Name: Content_Rating, dtype: int64

# %%
fig = px.pie(labels=ratings.index, values=ratings.values)
fig.show()
# Out:
# <div>                            <div id="e83398bd-6242-4cc8-a7e2-794a4880d39a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e83398bd-6242-4cc8-a7e2-794a4880d39a")) {                    Plotly.newPlot(                        "e83398bd-6242-4cc8-a7e2-794a4880d39a",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"value=%{value}<extra></extra>","legendgroup":"","name":"","showlegend":false,"values":[6621,912,357,305,3,1],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd37
# ...

# %%
fig = px.pie(labels=ratings.index, 
             values=ratings.values,
             title="Content Rating",
             names=ratings.index
            )

fig.update_traces(textposition="outside", textinfo="percent+label")

fig.show()
# Out:
# <div>                            <div id="ed359a33-d10c-406e-8ad4-5fa6d5cc12e3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ed359a33-d10c-406e-8ad4-5fa6d5cc12e3")) {                    Plotly.newPlot(                        "ed359a33-d10c-406e-8ad4-5fa6d5cc12e3",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}<br>value=%{value}<extra></extra>","labels":["Everyone","Teen","Mature 17+","Everyone 10+","Adults only 18+","Unrated"],"legendgroup":"","name":"","showlegend":true,"values":[6621,912,357,305,3,1],"type":"pie","textinfo":"percent+label","textposition":"outside"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks"
# ...

# %%
fig = px.pie(labels=ratings.index, 
             values=ratings.values,
             title="Content Rating",
             names=ratings.index,
             hole=0.6
            )

fig.update_traces(textposition="inside", textinfo="percent")

fig.show()
# Out:
# <div>                            <div id="4cc4de9d-4a39-447c-a792-070a740d07d4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4cc4de9d-4a39-447c-a792-070a740d07d4")) {                    Plotly.newPlot(                        "4cc4de9d-4a39-447c-a792-070a740d07d4",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.6,"hovertemplate":"label=%{label}<br>value=%{value}<extra></extra>","labels":["Everyone","Teen","Mature 17+","Everyone 10+","Adults only 18+","Unrated"],"legendgroup":"","name":"","showlegend":true,"values":[6621,912,357,305,3,1],"type":"pie","textinfo":"percent","textposition":"inside"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ti
# ...

# %% [markdown]
# # Numeric Type Conversion: Examine the Number of Installs
#
# **Challenge**: How many apps had over 1 billion (that's right - BILLION) installations? How many apps just had a single install?
#
# Check the datatype of the Installs column.
#
# Count the number of apps at each level of installations.
#
# Convert the number of installations (the Installs column) to a numeric data type. Hint: this is a 2-step process. You'll have make sure you remove non-numeric characters first.

# %%
df_apps_clean.Installs.describe()
# Out:
# count          8199
# unique           19
# top       1,000,000
# freq           1417
# Name: Installs, dtype: object

# %%
df_apps_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8199 entries, 21 to 10835
# Data columns (total 10 columns):
# App               8199 non-null object
# Category          8199 non-null object
# Rating            8199 non-null float64
# Reviews           8199 non-null int64
# Size_MBs          8199 non-null float64
# Installs          8199 non-null object
# Type              8199 non-null object
# Price             8199 non-null object
# Content_Rating    8199 non-null object
# Genres            8199 non-null object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 704.6+ KB

# %%
df_apps_clean[["App", "Installs"]].groupby("Installs").count()
# Out:
#                 App
# Installs
# 1                 3
# 1,000           698
# 1,000,000      1417
# 1,000,000,000    20
# 10               69
# 10,000          988
# 10,000,000      933
# 100             303
# 100,000        1096
# 100,000,000     189
# 5                 9
# 5,000           425
# 5,000,000       607
# 50               56
# 50,000          457
# 50,000,000      202
# 500             199
# 500,000         504
# 500,000,000      24

# %%
df_apps_clean.Installs = df_apps_clean.Installs.astype(str).str.replace(",", "")
df_apps_clean.Installs = pd.to_numeric(df_apps_clean.Installs)
df_apps_clean[["App", "Installs"]].groupby("Installs").count()
# Out:
#              App
# Installs
# 1              3
# 5              9
# 10            69
# 50            56
# 100          303
# 500          199
# 1000         698
# 5000         425
# 10000        988
# 50000        457
# 100000      1096
# 500000       504
# 1000000     1417
# 5000000      607
# 10000000     933
# 50000000     202
# 100000000    189
# 500000000     24
# 1000000000    20

# %% [markdown]
# # Find the Most Expensive Apps, Filter out the Junk, and Calculate a (ballpark) Sales Revenue Estimate
#
# Let's examine the Price column more closely.
#
# **Challenge**: Convert the price column to numeric data. Then investigate the top 20 most expensive apps in the dataset.
#
# Remove all apps that cost more than $250 from the `df_apps_clean` DataFrame.
#
# Add a column called 'Revenue_Estimate' to the DataFrame. This column should hold the price of the app times the number of installs. What are the top 10 highest grossing paid apps according to this estimate? Out of the top 10 highest grossing paid apps, how many are games?

# %%
df_apps_clean.Price = df_apps_clean.Price.astype("str").str.replace("$", "")
df_apps_clean.Price = pd.to_numeric(df_apps_clean.Price)
df_apps_clean_sub250 = df_apps_clean[df_apps_clean.Price < 250]

# %% [markdown]
# ### The most expensive apps sub $250

# %%
df_apps_clean_sub250["Revenue_Estimate"] = df_apps_clean_sub250.Price * df_apps_clean_sub250.Installs
df_apps_clean_sub250.sort_values("Price").tail()
# Out:
# C:\Users\Chris\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                             App   Category  Rating  Reviews  Size_MBs  \
# 2207                   EMT PASS    MEDICAL    3.40       51      2.40
# 2481    A Manual of Acupuncture    MEDICAL    3.50      214     68.00
# 2629           I am Rich Person  LIFESTYLE    4.20      134      1.80
# 1407               LTC AS Legal    MEDICAL    4.00        6      1.30
# 2281  Vargo Anesthesia Mega App    MEDICAL    4.60       92     32.00
#
#       Installs  Type  Price Content_Rating     Genres  Revenue_Estimate
# 2207      1000  Paid  29.99       Everyone    Medical         29,990.00
# ...

# %% [markdown]
# ### Highest Grossing Paid Apps (ballpark estimate)

# %%
df_apps_clean_sub250.sort_values("Revenue_Estimate").tail(10)
# Out:
#                                 App     Category  Rating  Reviews  Size_MBs  \
# 7044                         Tasker        TOOLS    4.60    43045      3.40
# 6746     Card Wars - Adventure Time       FAMILY    4.30   129603     23.00
# 7954                    Bloons TD 5       FAMILY    4.60   190086     94.00
# 6082                   Weather Live      WEATHER    4.50    76593      4.75
# 6594            DraStic DS Emulator         GAME    4.60    87766     12.00
# 7977        Sleep as Android Unlock    LIFESTYLE    4.50    23966      0.85
# 7477            Facetune - For Free  PHOTOGRAPHY    4.40    49553     48.00
# 7151  Grand Theft Auto: San Andreas         GAME    4.40   348962     26.00
# 8825                  Hitman Sniper         GAME    4.60   408292     29.00
# 9220                      Minecraft       FAMILY    4.50  2376564     19.00
#
#       Installs  Type  Price Content_Rating                     Genres  \
# ...

# %% [markdown]
# # Plotly Bar Charts & Scatter Plots: Analysing App Categories

# %%
df_apps_clean_sub250.Category.nunique()
# Out:
# 33

# %%
top10_category = df_apps_clean_sub250.Category.value_counts()[:10]
top10_category
# Out:
# FAMILY             1606
# GAME                910
# TOOLS               719
# PRODUCTIVITY        301
# PERSONALIZATION     298
# LIFESTYLE           297
# FINANCE             296
# MEDICAL             292
# PHOTOGRAPHY         263
# BUSINESS            262
# Name: Category, dtype: int64

# %% [markdown]
# ### Vertical Bar Chart - Highest Competition (Number of Apps)

# %%
bar = px.bar(x = top10_category.index, y = top10_category.values)
bar.show()
# Out:
# <div>                            <div id="26b30456-2090-41f0-a101-f565218ccf11" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("26b30456-2090-41f0-a101-f565218ccf11")) {                    Plotly.newPlot(                        "26b30456-2090-41f0-a101-f565218ccf11",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["FAMILY","GAME","TOOLS","PRODUCTIVITY","PERSONALIZATION","LIFESTYLE","FINANCE","MEDICAL","PHOTOGRAPHY","BUSINESS"],"xaxis":"x","y":[1606,910,719,301,298,297,296,292,263,262],"yaxis":"y","type":"bar"}],                        {"templ
# ...

# %% [markdown]
# ### Horizontal Bar Chart - Most Popular Categories (Highest Downloads)

# %%
category_installs = df_apps_clean.groupby("Category").agg({"Installs": pd.Series.sum})
category_installs.sort_values("Installs", ascending=True, inplace=True)

# %%
h_bar = px.bar(x = category_installs.Installs,
              y = category_installs.index,
              orientation="h")

h_bar.update_layout(xaxis_title="Number of Downloads", yaxis_title="Category")

h_bar.show()
# Out:
# <div>                            <div id="883dee31-9d5e-4bcb-b0ca-af6a0d4cdc0e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("883dee31-9d5e-4bcb-b0ca-af6a0d4cdc0e")) {                    Plotly.newPlot(                        "883dee31-9d5e-4bcb-b0ca-af6a0d4cdc0e",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[15949410,26916200,31116110,39162676,44931100,52083000,53129800,97082000,114233100,140912410,211677750,352852000,361096500,455312400,503267560,503742120,692018120,1096431465,1134006220,1400331540,1532352930,1665791655,2113660000,2369
# ...

# %% [markdown]
# ### Category Concentration - Downloads vs. Competition
#
# **Challenge**:
# * First, create a DataFrame that has the number of apps in one column and the number of installs in another:
#
# <img src=https://imgur.com/uQRSlXi.png width="350">
#
# * Then use the [plotly express examples from the documentation](https://plotly.com/python/line-and-scatter/) alongside the [.scatter() API reference](https://plotly.com/python-api-reference/generated/plotly.express.scatter.html)to create scatter plot that looks like this.
#
# <img src=https://imgur.com/cHsqh6a.png>
#
# *Hint*: Use the size, hover_name and color parameters in .scatter(). To scale the yaxis, call .update_layout() and specify that the yaxis should be on a log-scale like so: yaxis=dict(type='log')

# %%
install_by_category = df_apps_clean_sub250.groupby("Category").agg({"App": pd.Series.count, "Installs": pd.Series.sum})
print(install_by_category.shape)
install_by_category.head()
# Out:
# (33, 2)
#                      App    Installs
# Category
# ART_AND_DESIGN        61   114233100
# AUTO_AND_VEHICLES     73    53129800
# BEAUTY                42    26916200
# BOOKS_AND_REFERENCE  169  1665791655
# BUSINESS             262   692018120

# %%
scatter = px.scatter(install_by_category, 
                     x="App", 
                     y="Installs",
                     title="Category Concentration",
                     size="App",
                     hover_name=install_by_category.index,
                     color="Installs")

scatter.update_layout(yaxis=dict(type="log"),
                     yaxis_title="Installs",
                     xaxis_title="Number of Apps")

scatter.show()
# Out:
# <div>                            <div id="53a0b7ae-ef6f-435e-8609-1223d55c8082" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("53a0b7ae-ef6f-435e-8609-1223d55c8082")) {                    Plotly.newPlot(                        "53a0b7ae-ef6f-435e-8609-1223d55c8082",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>App=%{marker.size}<br>Installs=%{marker.color}<extra></extra>","hovertext":["ART_AND_DESIGN","AUTO_AND_VEHICLES","BEAUTY","BOOKS_AND_REFERENCE","BUSINESS","COMICS","COMMUNICATION","DATING","EDUCATION","ENTERTAINMENT","EVENTS","FAMILY","FINANCE","FOOD_AND_DRINK","GAME","HEALTH_AND_FITNESS","HOUSE_AND_HOME","LIBRARIES_AND_DEMO","LIFESTYLE","MAPS_AND_NAVIGATION","MEDICAL","NEWS_AND_MAGAZINES","PARENTING","PERSONALIZATION"
# ...

# %% [markdown]
# # Extracting Nested Data from a Column
#
# **Challenge**: How many different types of genres are there? Can an app belong to more than one genre? Check what happens when you use .value_counts() on a column with nested values? See if you can work around this problem by using the .split() function and the DataFrame's [.stack() method](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.stack.html).

# %%
stack = df_apps_clean_sub250.Genres.str.split(";", expand=True).stack()
num_genres = stack.value_counts()
print(num_genres)
# Out:
# Tools                      719
# Education                  587
# Entertainment              498
# Action                     304
# Productivity               301
# Lifestyle                  298
# Personalization            298
# Finance                    296
# Medical                    292
# Sports                     270
# Photography                263
# Business                   262
# Communication              258
# Health & Fitness           245
# Casual                     216
# News & Magazines           204
# Social                     203
# Simulation                 200
# Travel & Local             187
# Arcade                     185
# Shopping                   180
# Books & Reference          171
# Video Players & Editors    150
# Dating                     134
# Puzzle                     124
# Maps & Navigation          118
# Role Playing               111
# Racing                     103
# Action & Adventure          96
# Strategy                    95
# ...

# %% [markdown]
# # Colour Scales in Plotly Charts - Competition in Genres

# %% [markdown]
# **Challenge**: Can you create this chart with the Series containing the genre data?
#
# <img src=https://imgur.com/DbcoQli.png width=400>
#
# Try experimenting with the built in colour scales in Plotly. You can find a full list [here](https://plotly.com/python/builtin-colorscales/).
#
# * Find a way to set the colour scale using the color_continuous_scale parameter.
# * Find a way to make the color axis disappear by using coloraxis_showscale.

# %%
genre_bars = px.bar(num_genres[:15], 
                    x=num_genres[:15].index, 
                    y=num_genres[:15].values,
                    title="Top Genres",
                    hover_name=num_genres[:15].index,
                    color=num_genres[:15].index,
                    color_continuous_scale="Agsunset")
bar.update_layout(xaxis_title="Genre",
                  yaxis_title="Number of Apps",
                  coloraxis_showscale=False)
genre_bars.show()
# Out:
# <div>                            <div id="d92cee88-6917-49d8-bede-0dd7c4418989" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d92cee88-6917-49d8-bede-0dd7c4418989")) {                    Plotly.newPlot(                        "d92cee88-6917-49d8-bede-0dd7c4418989",                        [{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>color=Tools<br>x=%{x}<br>y=%{y}<extra></extra>","hovertext":["Tools"],"legendgroup":"Tools","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Tools","offsetgroup":"Tools","orientation":"v","showlegend":true,"textposition":"auto","x":["Tools"],"xaxis":"x","y":[719],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>color=Education<br>x=%{x}<br
# ...

# %% [markdown]
# # Grouped Bar Charts: Free vs. Paid Apps per Category

# %%
df_free_vs_paid = df_apps_clean_sub250.groupby(["Category", "Type"], as_index=False).agg({"App": pd.Series.count})
df_free_vs_paid.head()
# Out:
#             Category  Type  App
# 0     ART_AND_DESIGN  Free   58
# 1     ART_AND_DESIGN  Paid    3
# 2  AUTO_AND_VEHICLES  Free   72
# 3  AUTO_AND_VEHICLES  Paid    1
# 4             BEAUTY  Free   42

# %% [markdown]
# **Challenge**: Use the plotly express bar [chart examples](https://plotly.com/python/bar-charts/#bar-chart-with-sorted-or-ordered-categories) and the [.bar() API reference](https://plotly.com/python-api-reference/generated/plotly.express.bar.html#plotly.express.bar) to create this bar chart:
#
# <img src=https://imgur.com/LE0XCxA.png>
#
# You'll want to use the `df_free_vs_paid` DataFrame that you created above that has the total number of free and paid apps per category.
#
# See if you can figure out how to get the look above by changing the `categoryorder` to 'total descending' as outlined in the documentation here [here](https://plotly.com/python/categorical-axes/#automatically-sorting-categories-by-name-or-total-value).

# %%
free_v_paid = px.bar(df_free_vs_paid, 
                     x="Category", 
                     y="App",
                     color="Type")


free_v_paid.update_layout(title="Free vs Paid Apps by Category",
                          xaxis_tickfont_size=14,
                          yaxis=dict(title="Number of Apps",
                                     title_font_size=16,
                                     tickfont_size=14,
                                     type="log"),
                          xaxis={"categoryorder": "total descending"},
                          barmode="group",
                          bargap=0.15,
                          bargroupgap=0.1,)

free_v_paid.show()
# Out:
# <div>                            <div id="9ab144da-5545-425b-93ab-dcad2526b1c1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9ab144da-5545-425b-93ab-dcad2526b1c1")) {                    Plotly.newPlot(                        "9ab144da-5545-425b-93ab-dcad2526b1c1",                        [{"alignmentgroup":"True","hovertemplate":"Type=Free<br>Category=%{x}<br>App=%{y}<extra></extra>","legendgroup":"Free","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Free","offsetgroup":"Free","orientation":"v","showlegend":true,"textposition":"auto","x":["ART_AND_DESIGN","AUTO_AND_VEHICLES","BEAUTY","BOOKS_AND_REFERENCE","BUSINESS","COMICS","COMMUNICATION","DATING","EDUCATION","ENTERTAINMENT","EVENTS","FAMILY","FINANCE","FOOD_AND_DRINK","GAME","HEALT
# ...

# %% [markdown]
# # Plotly Box Plots: Lost Downloads for Paid Apps
#
# **Challenge**: Create a box plot that shows the number of Installs for free versus paid apps. How does the median number of installations compare? Is the difference large or small?
#
# Use the [Box Plots Guide](https://plotly.com/python/box-plots/) and the [.box API reference](https://plotly.com/python-api-reference/generated/plotly.express.box.html) to create the following chart.
#
# <img src=https://imgur.com/uVsECT3.png>

# %%
box_installs = px.box(df_apps_clean_sub250, 
                      y="Installs", 
                      x="Type", 
                      color="Type",
                      notched=True,
                      points="all",
                      title="How Many Downloads are Paid Apps Giving Up?")

box_installs.update_layout(yaxis=dict(type="log"))

box_installs.show()
# Out:
# <div>                            <div id="07fdb876-0f25-4452-a9b9-9e586fbb6167" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("07fdb876-0f25-4452-a9b9-9e586fbb6167")) {                    Plotly.newPlot(                        "07fdb876-0f25-4452-a9b9-9e586fbb6167",                        [{"alignmentgroup":"True","boxpoints":"all","hovertemplate":"Type=%{x}<br>Installs=%{y}<extra></extra>","legendgroup":"Free","marker":{"color":"#636efa"},"name":"Free","notched":true,"offsetgroup":"Free","orientation":"v","showlegend":true,"x":["Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free"
# ...

# %% [markdown]
# # Plotly Box Plots: Revenue by App Category
#
# **Challenge**: See if you can generate the chart below:
#
# <img src=https://imgur.com/v4CiNqX.png>
#
# Looking at the hover text, how much does the median app earn in the Tools category? If developing an Android app costs $30,000 or thereabouts, does the average photography app recoup its development costs?
#
# Hint: I've used 'min ascending' to sort the categories.

# %%
df_paid_apps = df_apps_clean_sub250[df_apps_clean_sub250["Type"] == "Paid"]

box_revenue = px.box(df_paid_apps, 
                     x="Category", 
                     y="Revenue_Estimate",
                     title="How Much Can Paid Apps Earn",
                     )

box_revenue.update_layout(yaxis=dict(type="log"),
                          xaxis={"categoryorder": "min ascending"})

box_revenue.show()
# Out:
# <div>                            <div id="416d9864-71e2-4e64-a546-6988f9e56b10" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("416d9864-71e2-4e64-a546-6988f9e56b10")) {                    Plotly.newPlot(                        "416d9864-71e2-4e64-a546-6988f9e56b10",                        [{"alignmentgroup":"True","hovertemplate":"Category=%{x}<br>Revenue_Estimate=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["GAME","GAME","FAMILY","BUSINESS","LIFESTYLE","FAMILY","PERSONALIZATION","PHOTOGRAPHY","FAMILY","GAME","PRODUCTIVITY","PHOTOGRAPHY","FAMILY","TOOLS","TOOLS","PERSONALIZATION","FAMILY","FAMILY","FAMILY","FAMILY","GAME","TOOLS","PERSONALIZAT
# ...

# %% [markdown]
# # How Much Can You Charge? Examine Paid App Pricing Strategies by Category
#
# **Challenge**: What is the median price price for a paid app? Then compare pricing by category by creating another box plot. But this time examine the prices (instead of the revenue estimates) of the paid apps. I recommend using `{categoryorder':'max descending'}` to sort the categories.

# %%
df_paid_apps.Price.median()
# Out:
# 2.99

# %%
box_median_price = px.box(df_paid_apps,
                          x="Category",
                          y="Price",
                          title="Price per Category")

box_median_price.update_layout(xaxis_title="Category",
                  yaxis_title="Paid App Price",
                  xaxis={"categoryorder": "max descending"},
                  yaxis=dict(type="log"))

box_median_price.show()
# Out:
# <div>                            <div id="9251a083-4fdf-48d9-8837-c8d72afd0c4b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9251a083-4fdf-48d9-8837-c8d72afd0c4b")) {                    Plotly.newPlot(                        "9251a083-4fdf-48d9-8837-c8d72afd0c4b",                        [{"alignmentgroup":"True","hovertemplate":"Category=%{x}<br>Price=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["GAME","GAME","FAMILY","BUSINESS","LIFESTYLE","FAMILY","PERSONALIZATION","PHOTOGRAPHY","FAMILY","GAME","PRODUCTIVITY","PHOTOGRAPHY","FAMILY","TOOLS","TOOLS","PERSONALIZATION","FAMILY","FAMILY","FAMILY","FAMILY","GAME","TOOLS","PERSONALIZATION","PERSO
# ...
